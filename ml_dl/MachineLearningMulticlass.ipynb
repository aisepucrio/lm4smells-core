# %% [markdown]
# ## Import the libraries

# %%
# !pip3 install dataframe_image
# !pip3 install pycaret
# !pip3 install pandas

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pycaret.classification import *
from sklearn.metrics import classification_report
#import dataframe_image as dfi

# %% [markdown]
# ##### Put the target on the end of the dataframe. Here, as an example, our target is the presence of Long Method.

# %% [markdown]
# #### Setup the model creation with pycaret

# %%
df = pd.read_csv('../dataset_ml_dl_v33.csv')
df
# Out:
#        raw_sloc  raw_multi  raw_blank  raw_single_comments  hal_func_N2  \
# 0             3          9          3                    0            0
# 1            13          0          1                    0            2
# 2            11          0          0                    0            2
# 3             5          0          0                    0            2
# 4             4         12          2                    0            0
# ...         ...        ...        ...                  ...          ...
# 11521         6          0          0                    0            4
# 11522         6          0          0                    0            2
# 11523        39          0          0                    0           15
# 11524         9          0          0                    0            0
# 11525         7          0          0                    0            3
#
#        hal_func_vocabulary  hal_func_length  hal_func_calculated_length  \
# 0                        0                0                    0.000000
# 1                        3                3                    2.000000
# 2                        3                3                    2.000000
# 3                        3                3                    2.000000
# 4                        0                0                    0.000000
# ...                    ...              ...                         ...
# 11521                    6                6                   10.000000
# 11522                    3                3                    2.000000
# 11523                   21               23                   72.954453
# 11524                    0                0                    0.000000
# 11525                    5                5                    6.754888
#
#        hal_func_volume  hal_func_difficulty  hal_func_effort  hal_func_time  \
# 0             0.000000                 0.00         0.000000       0.000000
# 1             4.754888                 0.50         2.377444       0.132080
# 2             4.754888                 0.50         2.377444       0.132080
# 3             4.754888                 0.50         2.377444       0.132080
# 4             0.000000                 0.00         0.000000       0.000000
# ...                ...                  ...              ...            ...
# 11521        15.509775                 1.00        15.509775       0.861654
# 11522         4.754888                 0.50         2.377444       0.132080
# 11523       101.023301                 3.75       378.837378      21.046521
# 11524         0.000000                 0.00         0.000000       0.000000
# 11525        11.609640                 1.00        11.609640       0.644980
#
#        hal_func_bugs          smell_label
# 0           0.000000      non-long-method
# 1           0.001585      non-long-method
# 2           0.001585      non-long-method
# 3           0.001585      non-long-method
# 4           0.000000      non-long-method
# ...              ...                  ...
# 11521       0.005170  long-parameter-list
# 11522       0.001585  long-parameter-list
# 11523       0.033674  long-parameter-list
# 11524       0.000000  long-parameter-list
# 11525       0.003870  long-parameter-list
#
# [11526 rows x 14 columns]

# %%
s = setup(data=df, target='smell_label', feature_selection=True,
          remove_multicollinearity=True,
          multicollinearity_threshold=0.85,
          feature_selection_method='classic',
          fix_imbalance=True, fold=10,index=False)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001178 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 29344, number of used features: 6
# [LightGBM] [Info] Start training from score -1.386294
# [LightGBM] [Info] Start training from score -1.386294
# [LightGBM] [Info] Start training from score -1.386294
# [LightGBM] [Info] Start training from score -1.386294
# <style type="text/css">
# #T_4000d_row9_col1, #T_4000d_row13_col1, #T_4000d_row15_col1, #T_4000d_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4000d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4000d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4000d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4000d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4000d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4000d_row0_col1" class="data row0 col1" >8713</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4000d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4000d_row1_col1" class="data row1 col1" >smell_label</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4000d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4000d_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4000d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_4000d_row3_col1" class="data row3 col1" >long-method: 0, long-parameter-list: 1, non-long-method: 2, non-long-parameter-list: 3</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4000d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_4000d_row4_col1" class="data row4 col1" >(11526, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4000d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_4000d_row5_col1" class="data row5 col1" >(32802, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4000d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_4000d_row6_col1" class="data row6 col1" >(29344, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4000d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_4000d_row7_col1" class="data row7 col1" >(3458, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4000d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4000d_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4000d_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4000d_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4000d_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4000d_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4000d_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4000d_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4000d_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4000d_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4000d_row13_col0" class="data row13 col0" >Remove multicollinearity</td>
#       <td id="T_4000d_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4000d_row14_col0" class="data row14 col0" >Multicollinearity threshold</td>
#       <td id="T_4000d_row14_col1" class="data row14 col1" >0.850000</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4000d_row15_col0" class="data row15 col0" >Fix imbalance</td>
#       <td id="T_4000d_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4000d_row16_col0" class="data row16 col0" >Fix imbalance method</td>
#       <td id="T_4000d_row16_col1" class="data row16 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4000d_row17_col0" class="data row17 col0" >Feature selection</td>
#       <td id="T_4000d_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4000d_row18_col0" class="data row18 col0" >Feature selection method</td>
#       <td id="T_4000d_row18_col1" class="data row18 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4000d_row19_col0" class="data row19 col0" >Feature selection estimator</td>
#       <td id="T_4000d_row19_col1" class="data row19 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4000d_row20_col0" class="data row20 col0" >Number of features selected</td>
#       <td id="T_4000d_row20_col1" class="data row20 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4000d_row21_col0" class="data row21 col0" >Fold Generator</td>
#       <td id="T_4000d_row21_col1" class="data row21 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4000d_row22_col0" class="data row22 col0" >Fold Number</td>
#       <td id="T_4000d_row22_col1" class="data row22 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_4000d_row23_col0" class="data row23 col0" >CPU Jobs</td>
#       <td id="T_4000d_row23_col1" class="data row23 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_4000d_row24_col0" class="data row24 col0" >Use GPU</td>
#       <td id="T_4000d_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_4000d_row25_col0" class="data row25 col0" >Log Experiment</td>
#       <td id="T_4000d_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_4000d_row26_col0" class="data row26 col0" >Experiment Name</td>
#       <td id="T_4000d_row26_col1" class="data row26 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4000d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_4000d_row27_col0" class="data row27 col0" >USI</td>
#       <td id="T_4000d_row27_col1" class="data row27 col1" >806b</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = get_config('X')
df
# Out:
#        raw_sloc  raw_multi  raw_blank  raw_single_comments  hal_func_N2  \
# 0             2          0          0                    0            0
# 1            17          0          0                    0           10
# 2             9          0          0                    0            1
# 3             2          0          0                    1            0
# 4             7          0          1                    0            0
# ...         ...        ...        ...                  ...          ...
# 11521         9          9          3                    0            2
# 11522         6          0          0                    0            6
# 11523        11          5          1                    0            0
# 11524         2          0          0                    0            0
# 11525         2          0          0                    0            0
#
#        hal_func_vocabulary  hal_func_length  hal_func_calculated_length  \
# 0                        0                0                    0.000000
# 1                       11               17                   30.529325
# 2                        2                2                    0.000000
# 3                        0                0                    0.000000
# 4                        0                0                    0.000000
# ...                    ...              ...                         ...
# 11521                    3                3                    2.000000
# 11522                    9                9                   20.264662
# 11523                    0                0                    0.000000
# 11524                    0                0                    0.000000
# 11525                    0                0                    0.000000
#
#        hal_func_volume  hal_func_difficulty  hal_func_effort  hal_func_time  \
# 0             0.000000             0.000000         0.000000       0.000000
# 1            58.810337             1.111111        65.344818       3.630268
# 2             2.000000             0.500000         1.000000       0.055556
# 3             0.000000             0.000000         0.000000       0.000000
# 4             0.000000             0.000000         0.000000       0.000000
# ...                ...                  ...              ...            ...
# 11521         4.754888             0.500000         2.377444       0.132080
# 11522        28.529325             1.500000        42.793987       2.377444
# 11523         0.000000             0.000000         0.000000       0.000000
# 11524         0.000000             0.000000         0.000000       0.000000
# 11525         0.000000             0.000000         0.000000       0.000000
#
#        hal_func_bugs
# 0           0.000000
# 1           0.019603
# 2           0.000667
# 3           0.000000
# 4           0.000000
# ...              ...
# 11521       0.001585
# 11522       0.009510
# 11523       0.000000
# 11524       0.000000
# 11525       0.000000
#
# [11526 rows x 13 columns]

# %% [markdown]
# ##### Train the models. In this code the model was trained for the Long Method smell. From all models, we selected the top-5 in terms of F1.

# %%
top5_models = compare_models(n_select=13, sort='f1')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             18:32:05
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_e6070 th {
#   text-align: left;
# }
# #T_e6070_row0_col0, #T_e6070_row0_col2, #T_e6070_row0_col4, #T_e6070_row0_col7, #T_e6070_row1_col0, #T_e6070_row1_col1, #T_e6070_row1_col2, #T_e6070_row1_col3, #T_e6070_row1_col4, #T_e6070_row1_col5, #T_e6070_row1_col6, #T_e6070_row1_col7, #T_e6070_row2_col0, #T_e6070_row2_col1, #T_e6070_row2_col2, #T_e6070_row2_col3, #T_e6070_row2_col4, #T_e6070_row2_col5, #T_e6070_row2_col6, #T_e6070_row2_col7, #T_e6070_row3_col0, #T_e6070_row3_col1, #T_e6070_row3_col2, #T_e6070_row3_col3, #T_e6070_row3_col4, #T_e6070_row3_col5, #T_e6070_row3_col6, #T_e6070_row3_col7, #T_e6070_row4_col0, #T_e6070_row4_col1, #T_e6070_row4_col3, #T_e6070_row4_col4, #T_e6070_row4_col5, #T_e6070_row4_col6, #T_e6070_row4_col7, #T_e6070_row5_col0, #T_e6070_row5_col1, #T_e6070_row5_col2, #T_e6070_row5_col3, #T_e6070_row5_col4, #T_e6070_row5_col5, #T_e6070_row5_col6, #T_e6070_row6_col0, #T_e6070_row6_col1, #T_e6070_row6_col2, #T_e6070_row6_col3, #T_e6070_row6_col4, #T_e6070_row6_col5, #T_e6070_row6_col6, #T_e6070_row6_col7, #T_e6070_row7_col0, #T_e6070_row7_col1, #T_e6070_row7_col2, #T_e6070_row7_col3, #T_e6070_row7_col5, #T_e6070_row7_col6, #T_e6070_row7_col7, #T_e6070_row8_col0, #T_e6070_row8_col1, #T_e6070_row8_col2, #T_e6070_row8_col3, #T_e6070_row8_col4, #T_e6070_row8_col5, #T_e6070_row8_col6, #T_e6070_row8_col7, #T_e6070_row9_col0, #T_e6070_row9_col1, #T_e6070_row9_col2, #T_e6070_row9_col3, #T_e6070_row9_col4, #T_e6070_row9_col5, #T_e6070_row9_col6, #T_e6070_row9_col7, #T_e6070_row10_col0, #T_e6070_row10_col1, #T_e6070_row10_col2, #T_e6070_row10_col3, #T_e6070_row10_col4, #T_e6070_row10_col5, #T_e6070_row10_col6, #T_e6070_row10_col7, #T_e6070_row11_col0, #T_e6070_row11_col1, #T_e6070_row11_col2, #T_e6070_row11_col3, #T_e6070_row11_col4, #T_e6070_row11_col5, #T_e6070_row11_col6, #T_e6070_row11_col7, #T_e6070_row12_col0, #T_e6070_row12_col1, #T_e6070_row12_col2, #T_e6070_row12_col3, #T_e6070_row12_col4, #T_e6070_row12_col5, #T_e6070_row12_col6, #T_e6070_row12_col7, #T_e6070_row13_col0, #T_e6070_row13_col1, #T_e6070_row13_col2, #T_e6070_row13_col3, #T_e6070_row13_col4, #T_e6070_row13_col5, #T_e6070_row13_col6, #T_e6070_row13_col7 {
#   text-align: left;
# }
# #T_e6070_row0_col1, #T_e6070_row0_col3, #T_e6070_row0_col5, #T_e6070_row0_col6, #T_e6070_row4_col2, #T_e6070_row5_col7, #T_e6070_row7_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e6070_row0_col8, #T_e6070_row1_col8, #T_e6070_row2_col8, #T_e6070_row3_col8, #T_e6070_row4_col8, #T_e6070_row5_col8, #T_e6070_row6_col8, #T_e6070_row7_col8, #T_e6070_row8_col8, #T_e6070_row9_col8, #T_e6070_row10_col8, #T_e6070_row11_col8, #T_e6070_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e6070_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e6070">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6070_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e6070_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e6070_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e6070_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e6070_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e6070_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e6070_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e6070_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e6070_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6070_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_e6070_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_e6070_row0_col1" class="data row0 col1" >0.8099</td>
#       <td id="T_e6070_row0_col2" class="data row0 col2" >0.6236</td>
#       <td id="T_e6070_row0_col3" class="data row0 col3" >0.8099</td>
#       <td id="T_e6070_row0_col4" class="data row0 col4" >0.8573</td>
#       <td id="T_e6070_row0_col5" class="data row0 col5" >0.8290</td>
#       <td id="T_e6070_row0_col6" class="data row0 col6" >0.1617</td>
#       <td id="T_e6070_row0_col7" class="data row0 col7" >0.1704</td>
#       <td id="T_e6070_row0_col8" class="data row0 col8" >0.6950</td>
#     </tr>
#     <tr>
#       <th id="T_e6070_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_e6070_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_e6070_row1_col1" class="data row1 col1" >0.5322</td>
#       <td id="T_e6070_row1_col2" class="data row1 col2" >0.6641</td>
#       <td id="T_e6070_row1_col3" class="data row1 col3" >0.5322</td>
#       <td id="T_e6070_row1_col4" class="data row1 col4" >0.8716</td>
#       <td id="T_e6070_row1_col5" class="data row1 col5" >0.6346</td>
#       <td id="T_e6070_row1_col6" class="data row1 col6" >0.0957</td>
#       <td id="T_e6070_row1_col7" class="data row1 col7" >0.1572</td>
#       <td id="T_e6070_row1_col8" class="data row1 col8" >1.4290</td>
#     </tr>
#     <tr>
#       <th id="T_e6070_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_e6070_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_e6070_row2_col1" class="data row2 col1" >0.5311</td>
#       <td id="T_e6070_row2_col2" class="data row2 col2" >0.6807</td>
#       <td id="T_e6070_row2_col3" class="data row2 col3" >0.5311</td>
#       <td id="T_e6070_row2_col4" class="data row2 col4" >0.8723</td>
#       <td id="T_e6070_row2_col5" class="data row2 col5" >0.6335</td>
#       <td id="T_e6070_row2_col6" class="data row2 col6" >0.0960</td>
#       <td id="T_e6070_row2_col7" class="data row2 col7" >0.1579</td>
#       <td id="T_e6070_row2_col8" class="data row2 col8" >1.9930</td>
#     </tr>
#     <tr>
#       <th id="T_e6070_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_e6070_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_e6070_row3_col1" class="data row3 col1" >0.5294</td>
#       <td id="T_e6070_row3_col2" class="data row3 col2" >0.6490</td>
#       <td id="T_e6070_row3_col3" class="data row3 col3" >0.5294</td>
#       <td id="T_e6070_row3_col4" class="data row3 col4" >0.8694</td>
#       <td id="T_e6070_row3_col5" class="data row3 col5" >0.6315</td>
#       <td id="T_e6070_row3_col6" class="data row3 col6" >0.0921</td>
#       <td id="T_e6070_row3_col7" class="data row3 col7" >0.1512</td>
#       <td id="T_e6070_row3_col8" class="data row3 col8" >0.7110</td>
#     </tr>
#     <tr>
#       <th id="T_e6070_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_e6070_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e6070_row4_col1" class="data row4 col1" >0.5209</td>
#       <td id="T_e6070_row4_col2" class="data row4 col2" >0.7000</td>
#       <td id="T_e6070_row4_col3" class="data row4 col3" >0.5209</td>
#       <td id="T_e6070_row4_col4" class="data row4 col4" >0.8784</td>
#       <td id="T_e6070_row4_col5" class="data row4 col5" >0.6251</td>
#       <td id="T_e6070_row4_col6" class="data row4 col6" >0.1024</td>
#       <td id="T_e6070_row4_col7" class="data row4 col7" >0.1721</td>
#       <td id="T_e6070_row4_col8" class="data row4 col8" >2.7400</td>
#     </tr>
#     <tr>
#       <th id="T_e6070_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_e6070_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_e6070_row5_col1" class="data row5 col1" >0.4929</td>
#       <td id="T_e6070_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_e6070_row5_col3" class="data row5 col3" >0.4929</td>
#       <td id="T_e6070_row5_col4" class="data row5 col4" >0.8800</td>
#       <td id="T_e6070_row5_col5" class="data row5 col5" >0.5999</td>
#       <td id="T_e6070_row5_col6" class="data row5 col6" >0.1002</td>
#       <td id="T_e6070_row5_col7" class="data row5 col7" >0.1736</td>

# %%
df2=pull()
df3 = pd.DataFrame(df2)
df3.to_latex('Multilabel_geral.latex',index=False)
df3.to_csv('Multilabel_geral.csv',index=False)
#dfi.export(df2, 'Bin_Blob_FS1.png')

# %% [markdown]
# ##### Result by Smell

# %%
from sklearn.metrics import classification_report
from pycaret.classification import predict_model

# Dicionário para armazenar os relatórios por modelo e por classe
reports = {}
# Lista para armazenar os dados
data = []

# Iterar sobre os modelos
for model in top5_models:
    # Gerar predições com o modelo individual
    predictions = predict_model(model)

    # Obter nome do modelo
    model_name = model.__class__.__name__

    # Gerar relatório por classe
    report = classification_report(
        predictions['smell_label'],
        predictions['prediction_label'],
        output_dict=True
    )

    # Armazenar o relatório
    reports[model_name] = report

    # Exibir e armazenar métricas por classe
    print(f"\n📊 Classification Report for {model_name}")
    for smell_class in ['long-method', 'long-parameter-list']:
        if smell_class in report:
            print(f"\nSmell: {smell_class}")
            print(f"  Accuracy: {report['accuracy']:.2f}")
            print(f"  Precision: {report[smell_class]['precision']:.2f}")
            print(f"  Recall: {report[smell_class]['recall']:.2f}")
            print(f"  F1-score: {report[smell_class]['f1-score']:.2f}")

            # Armazenar para eventual DataFrame
            data.append({
                "Model": model_name,
                "Smell": smell_class,
                "Accuracy": report["accuracy"],
                "Precision": report[smell_class]["precision"],
                "Recall": report[smell_class]["recall"],
                "F1-score": report[smell_class]["f1-score"]
            })
    print("=" * 80)
# Out:
# 📊 Classification Report for KNeighborsClassifier
#
# Smell: long-method
#   Accuracy: 0.82
#   Precision: 0.41
#   Recall: 0.71
#   F1-score: 0.52
#
# Smell: long-parameter-list
#   Accuracy: 0.82
#   Precision: 0.06
#   Recall: 0.28
#   F1-score: 0.10
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_cd2ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd2ed_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cd2ed_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cd2ed_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cd2ed_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cd2ed_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cd2ed_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cd2ed_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cd2ed_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd2ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd2ed_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_cd2ed_row0_col1" class="data row0 col1" >0.5081</td>
#       <td id="T_cd2ed_row0_col2" class="data row0 col2" >0.6441</td>
#       <td id="T_cd2ed_row0_col3" class="data row0 col3" >0.5081</td>
#       <td id="T_cd2ed_row0_col4" class="data row0 col4" >0.8628</td>
#       <td id="T_cd2ed_row0_col5" class="data row0 col5" >0.6131</td>
#       <td id="T_cd2ed_row0_col6" class="data row0 col6" >0.0793</td>
#       <td id="T_cd2ed_row0_col7" class="data row0 col7" >0.1352</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for ExtraTreesClassifier
#
# Smell: long-method
#   Accuracy: 0.51
#   Precision: 0.30
#   Recall: 0.61
#   F1-score: 0.40
#
# Smell: long-parameter-list
#   Accuracy: 0.51
#   Precision: 0.12
#   Recall: 0.22
#   F1-score: 0.15
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_45dfe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45dfe_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45dfe_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_45dfe_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_45dfe_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_45dfe_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_45dfe_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_45dfe_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_45dfe_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45dfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45dfe_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_45dfe_row0_col1" class="data row0 col1" >0.5072</td>
#       <td id="T_45dfe_row0_col2" class="data row0 col2" >0.6643</td>
#       <td id="T_45dfe_row0_col3" class="data row0 col3" >0.5072</td>
#       <td id="T_45dfe_row0_col4" class="data row0 col4" >0.8625</td>
#       <td id="T_45dfe_row0_col5" class="data row0 col5" >0.6123</td>
#       <td id="T_45dfe_row0_col6" class="data row0 col6" >0.0786</td>
#       <td id="T_45dfe_row0_col7" class="data row0 col7" >0.1340</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for RandomForestClassifier
#
# Smell: long-method
#   Accuracy: 0.51
#   Precision: 0.29
#   Recall: 0.61
#   F1-score: 0.39
#
# Smell: long-parameter-list
#   Accuracy: 0.51
#   Precision: 0.11
#   Recall: 0.20
#   F1-score: 0.14
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_3f987">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f987_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3f987_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3f987_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3f987_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3f987_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3f987_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3f987_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3f987_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f987_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f987_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_3f987_row0_col1" class="data row0 col1" >0.5093</td>
#       <td id="T_3f987_row0_col2" class="data row0 col2" >0.6262</td>
#       <td id="T_3f987_row0_col3" class="data row0 col3" >0.5093</td>
#       <td id="T_3f987_row0_col4" class="data row0 col4" >0.8593</td>
#       <td id="T_3f987_row0_col5" class="data row0 col5" >0.6144</td>
#       <td id="T_3f987_row0_col6" class="data row0 col6" >0.0726</td>
#       <td id="T_3f987_row0_col7" class="data row0 col7" >0.1230</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for DecisionTreeClassifier
#
# Smell: long-method
#   Accuracy: 0.51
#   Precision: 0.27
#   Recall: 0.54
#   F1-score: 0.36
#
# Smell: long-parameter-list
#   Accuracy: 0.51
#   Precision: 0.10
#   Recall: 0.15
#   F1-score: 0.12
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_10473">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10473_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_10473_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_10473_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_10473_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_10473_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_10473_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_10473_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_10473_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10473_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10473_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_10473_row0_col1" class="data row0 col1" >0.5093</td>
#       <td id="T_10473_row0_col2" class="data row0 col2" >0.6840</td>
#       <td id="T_10473_row0_col3" class="data row0 col3" >0.5093</td>
#       <td id="T_10473_row0_col4" class="data row0 col4" >0.8691</td>
#       <td id="T_10473_row0_col5" class="data row0 col5" >0.6145</td>
#       <td id="T_10473_row0_col6" class="data row0 col6" >0.0880</td>
#       <td id="T_10473_row0_col7" class="data row0 col7" >0.1506</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for LGBMClassifier
#
# Smell: long-method
#   Accuracy: 0.51
#   Precision: 0.33
#   Recall: 0.70
#   F1-score: 0.45
#
# Smell: long-parameter-list
#   Accuracy: 0.51
#   Precision: 0.09
#   Recall: 0.17
#   F1-score: 0.11
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_716b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_716b0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_716b0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_716b0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_716b0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_716b0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_716b0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_716b0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_716b0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_716b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_716b0_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_716b0_row0_col1" class="data row0 col1" >0.4740</td>
#       <td id="T_716b0_row0_col2" class="data row0 col2" >0.6866</td>
#       <td id="T_716b0_row0_col3" class="data row0 col3" >0.4740</td>
#       <td id="T_716b0_row0_col4" class="data row0 col4" >0.8679</td>
#       <td id="T_716b0_row0_col5" class="data row0 col5" >0.5816</td>
#       <td id="T_716b0_row0_col6" class="data row0 col6" >0.0826</td>
#       <td id="T_716b0_row0_col7" class="data row0 col7" >0.1458</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for GradientBoostingClassifier
#
# Smell: long-method
#   Accuracy: 0.47
#   Precision: 0.32
#   Recall: 0.74
#   F1-score: 0.45
#
# Smell: long-parameter-list
#   Accuracy: 0.47
#   Precision: 0.07
#   Recall: 0.32
#   F1-score: 0.12
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_5a098">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a098_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5a098_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5a098_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5a098_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5a098_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5a098_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5a098_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5a098_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a098_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a098_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_5a098_row0_col1" class="data row0 col1" >0.3117</td>
#       <td id="T_5a098_row0_col2" class="data row0 col2" >0.6507</td>
#       <td id="T_5a098_row0_col3" class="data row0 col3" >0.3117</td>
#       <td id="T_5a098_row0_col4" class="data row0 col4" >0.8655</td>
#       <td id="T_5a098_row0_col5" class="data row0 col5" >0.4084</td>
#       <td id="T_5a098_row0_col6" class="data row0 col6" >0.0543</td>
#       <td id="T_5a098_row0_col7" class="data row0 col7" >0.1222</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for LogisticRegression
#
# Smell: long-method
#   Accuracy: 0.31
#   Precision: 0.47
#   Recall: 0.72
#   F1-score: 0.57
#
# Smell: long-parameter-list
#   Accuracy: 0.31
#   Precision: 0.05
#   Recall: 0.38
#   F1-score: 0.08
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_36cd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36cd6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_36cd6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_36cd6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_36cd6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_36cd6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_36cd6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_36cd6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_36cd6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36cd6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36cd6_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_36cd6_row0_col1" class="data row0 col1" >0.2877</td>
#       <td id="T_36cd6_row0_col2" class="data row0 col2" >0.5894</td>
#       <td id="T_36cd6_row0_col3" class="data row0 col3" >0.2877</td>
#       <td id="T_36cd6_row0_col4" class="data row0 col4" >0.8723</td>
#       <td id="T_36cd6_row0_col5" class="data row0 col5" >0.3794</td>
#       <td id="T_36cd6_row0_col6" class="data row0 col6" >0.0524</td>
#       <td id="T_36cd6_row0_col7" class="data row0 col7" >0.1258</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for LinearDiscriminantAnalysis
#
# Smell: long-method
#   Accuracy: 0.29
#   Precision: 0.59
#   Recall: 0.71
#   F1-score: 0.64
#
# Smell: long-parameter-list
#   Accuracy: 0.29
#   Precision: 0.05
#   Recall: 0.37
#   F1-score: 0.09
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_ba342">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba342_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ba342_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ba342_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ba342_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ba342_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ba342_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ba342_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ba342_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba342_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba342_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_ba342_row0_col1" class="data row0 col1" >0.2736</td>
#       <td id="T_ba342_row0_col2" class="data row0 col2" >0.4435</td>
#       <td id="T_ba342_row0_col3" class="data row0 col3" >0.2736</td>
#       <td id="T_ba342_row0_col4" class="data row0 col4" >0.8665</td>
#       <td id="T_ba342_row0_col5" class="data row0 col5" >0.3590</td>
#       <td id="T_ba342_row0_col6" class="data row0 col6" >0.0521</td>
#       <td id="T_ba342_row0_col7" class="data row0 col7" >0.1198</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for AdaBoostClassifier
#
# Smell: long-method
#   Accuracy: 0.27
#   Precision: 0.36
#   Recall: 0.69
#   F1-score: 0.47
#
# Smell: long-parameter-list
#   Accuracy: 0.27
#   Precision: 0.04
#   Recall: 0.48
#   F1-score: 0.07
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_2b56e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b56e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2b56e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2b56e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2b56e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2b56e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2b56e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2b56e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2b56e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b56e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b56e_row0_col0" class="data row0 col0" >SVM - Linear Kernel</td>
#       <td id="T_2b56e_row0_col1" class="data row0 col1" >0.0674</td>
#       <td id="T_2b56e_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_2b56e_row0_col3" class="data row0 col3" >0.0674</td>
#       <td id="T_2b56e_row0_col4" class="data row0 col4" >0.0195</td>
#       <td id="T_2b56e_row0_col5" class="data row0 col5" >0.0228</td>
#       <td id="T_2b56e_row0_col6" class="data row0 col6" >0.0315</td>
#       <td id="T_2b56e_row0_col7" class="data row0 col7" >0.1075</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for SGDClassifier
#
# Smell: long-method
#   Accuracy: 0.07
#   Precision: 0.62
#   Recall: 0.65
#   F1-score: 0.64
#
# Smell: long-parameter-list
#   Accuracy: 0.07
#   Precision: 0.04
#   Recall: 0.65
#   F1-score: 0.07
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_6850d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6850d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6850d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6850d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6850d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6850d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6850d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6850d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6850d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6850d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6850d_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_6850d_row0_col1" class="data row0 col1" >0.1353</td>
#       <td id="T_6850d_row0_col2" class="data row0 col2" >0.6665</td>
#       <td id="T_6850d_row0_col3" class="data row0 col3" >0.1353</td>
#       <td id="T_6850d_row0_col4" class="data row0 col4" >0.8734</td>
#       <td id="T_6850d_row0_col5" class="data row0 col5" >0.1445</td>
#       <td id="T_6850d_row0_col6" class="data row0 col6" >0.0379</td>
#       <td id="T_6850d_row0_col7" class="data row0 col7" >0.1244</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for GaussianNB
#
# Smell: long-method
#   Accuracy: 0.14
#   Precision: 0.51
#   Recall: 0.72
#   F1-score: 0.60
#
# Smell: long-parameter-list
#   Accuracy: 0.14
#   Precision: 0.04
#   Recall: 0.40
#   F1-score: 0.08
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_2eeae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2eeae_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2eeae_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2eeae_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2eeae_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2eeae_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2eeae_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2eeae_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2eeae_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2eeae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2eeae_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_2eeae_row0_col1" class="data row0 col1" >0.0960</td>
#       <td id="T_2eeae_row0_col2" class="data row0 col2" >0.6711</td>
#       <td id="T_2eeae_row0_col3" class="data row0 col3" >0.0960</td>
#       <td id="T_2eeae_row0_col4" class="data row0 col4" >0.8494</td>
#       <td id="T_2eeae_row0_col5" class="data row0 col5" >0.0712</td>
#       <td id="T_2eeae_row0_col6" class="data row0 col6" >0.0355</td>
#       <td id="T_2eeae_row0_col7" class="data row0 col7" >0.1198</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for QuadraticDiscriminantAnalysis
#
# Smell: long-method
#   Accuracy: 0.10
#   Precision: 0.52
#   Recall: 0.76
#   F1-score: 0.62
#
# Smell: long-parameter-list
#   Accuracy: 0.10
#   Precision: 0.04
#   Recall: 0.46
#   F1-score: 0.07
# ================================================================================
# <style type="text/css">
# </style>
# <table id="T_46baa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46baa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_46baa_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_46baa_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_46baa_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_46baa_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_46baa_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_46baa_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_46baa_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46baa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46baa_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_46baa_row0_col1" class="data row0 col1" >0.0665</td>
#       <td id="T_46baa_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_46baa_row0_col3" class="data row0 col3" >0.0665</td>
#       <td id="T_46baa_row0_col4" class="data row0 col4" >0.6955</td>
#       <td id="T_46baa_row0_col5" class="data row0 col5" >0.0183</td>
#       <td id="T_46baa_row0_col6" class="data row0 col6" >0.0217</td>
#       <td id="T_46baa_row0_col7" class="data row0 col7" >0.1398</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Classification Report for RidgeClassifier
#
# Smell: long-method
#   Accuracy: 0.07
#   Precision: 0.29
#   Recall: 0.72
#   F1-score: 0.42
#
# Smell: long-parameter-list
#   Accuracy: 0.07
#   Precision: 0.20
#   Recall: 0.05
#   F1-score: 0.07
# ================================================================================

# %%
# Criar um DataFrame
df = pd.DataFrame(data)

# Salvar o DataFrame em um arquivo CSV
df.to_csv("smell_classification_Multilabel.csv", index=False)

# %%
df2=pull()
df3 = pd.DataFrame(df2)
df3.to_latex('multilabel_.latex',index=False)
df3.to_csv('multilabel.csv',index=False)

# %% [markdown]
# #### Ensemble the top-5 models

# %%
blended_models = blend_models(
  top5_models,
  choose_better=True,
  optimize="f1")
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           18:36:15
# Status     . . . . . . . . . . . . . . . . . .   Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Voting Classifier
# <style type="text/css">
# #T_ddb68_row10_col0, #T_ddb68_row10_col1, #T_ddb68_row10_col2, #T_ddb68_row10_col3, #T_ddb68_row10_col4, #T_ddb68_row10_col5, #T_ddb68_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ddb68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddb68_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ddb68_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ddb68_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ddb68_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ddb68_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ddb68_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ddb68_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddb68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ddb68_row0_col0" class="data row0 col0" >0.4114</td>
#       <td id="T_ddb68_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_ddb68_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_ddb68_row0_col3" class="data row0 col3" >0.8850</td>
#       <td id="T_ddb68_row0_col4" class="data row0 col4" >0.5211</td>
#       <td id="T_ddb68_row0_col5" class="data row0 col5" >0.0860</td>
#       <td id="T_ddb68_row0_col6" class="data row0 col6" >0.1686</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ddb68_row1_col0" class="data row1 col0" >0.3941</td>
#       <td id="T_ddb68_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_ddb68_row1_col2" class="data row1 col2" >0.3941</td>
#       <td id="T_ddb68_row1_col3" class="data row1 col3" >0.8787</td>
#       <td id="T_ddb68_row1_col4" class="data row1 col4" >0.5041</td>
#       <td id="T_ddb68_row1_col5" class="data row1 col5" >0.0748</td>
#       <td id="T_ddb68_row1_col6" class="data row1 col6" >0.1488</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ddb68_row2_col0" class="data row2 col0" >0.5105</td>
#       <td id="T_ddb68_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_ddb68_row2_col2" class="data row2 col2" >0.5105</td>
#       <td id="T_ddb68_row2_col3" class="data row2 col3" >0.8966</td>
#       <td id="T_ddb68_row2_col4" class="data row2 col4" >0.6185</td>
#       <td id="T_ddb68_row2_col5" class="data row2 col5" >0.1212</td>
#       <td id="T_ddb68_row2_col6" class="data row2 col6" >0.2107</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ddb68_row3_col0" class="data row3 col0" >0.3928</td>
#       <td id="T_ddb68_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_ddb68_row3_col2" class="data row3 col2" >0.3928</td>
#       <td id="T_ddb68_row3_col3" class="data row3 col3" >0.8943</td>
#       <td id="T_ddb68_row3_col4" class="data row3 col4" >0.5005</td>
#       <td id="T_ddb68_row3_col5" class="data row3 col5" >0.0860</td>
#       <td id="T_ddb68_row3_col6" class="data row3 col6" >0.1745</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ddb68_row4_col0" class="data row4 col0" >0.3903</td>
#       <td id="T_ddb68_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_ddb68_row4_col2" class="data row4 col2" >0.3903</td>
#       <td id="T_ddb68_row4_col3" class="data row4 col3" >0.8837</td>
#       <td id="T_ddb68_row4_col4" class="data row4 col4" >0.4967</td>
#       <td id="T_ddb68_row4_col5" class="data row4 col5" >0.0798</td>
#       <td id="T_ddb68_row4_col6" class="data row4 col6" >0.1643</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ddb68_row5_col0" class="data row5 col0" >0.4275</td>
#       <td id="T_ddb68_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_ddb68_row5_col2" class="data row5 col2" >0.4275</td>
#       <td id="T_ddb68_row5_col3" class="data row5 col3" >0.8836</td>
#       <td id="T_ddb68_row5_col4" class="data row5 col4" >0.5360</td>
#       <td id="T_ddb68_row5_col5" class="data row5 col5" >0.0899</td>
#       <td id="T_ddb68_row5_col6" class="data row5 col6" >0.1712</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ddb68_row6_col0" class="data row6 col0" >0.4498</td>
#       <td id="T_ddb68_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_ddb68_row6_col2" class="data row6 col2" >0.4498</td>
#       <td id="T_ddb68_row6_col3" class="data row6 col3" >0.8902</td>
#       <td id="T_ddb68_row6_col4" class="data row6 col4" >0.5607</td>
#       <td id="T_ddb68_row6_col5" class="data row6 col5" >0.0985</td>
#       <td id="T_ddb68_row6_col6" class="data row6 col6" >0.1842</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ddb68_row7_col0" class="data row7 col0" >0.3829</td>
#       <td id="T_ddb68_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_ddb68_row7_col2" class="data row7 col2" >0.3829</td>
#       <td id="T_ddb68_row7_col3" class="data row7 col3" >0.8779</td>
#       <td id="T_ddb68_row7_col4" class="data row7 col4" >0.4882</td>
#       <td id="T_ddb68_row7_col5" class="data row7 col5" >0.0770</td>
#       <td id="T_ddb68_row7_col6" class="data row7 col6" >0.1560</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ddb68_row8_col0" class="data row8 col0" >0.4181</td>
#       <td id="T_ddb68_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_ddb68_row8_col2" class="data row8 col2" >0.4181</td>
#       <td id="T_ddb68_row8_col3" class="data row8 col3" >0.8684</td>
#       <td id="T_ddb68_row8_col4" class="data row8 col4" >0.5305</td>
#       <td id="T_ddb68_row8_col5" class="data row8 col5" >0.0673</td>
#       <td id="T_ddb68_row8_col6" class="data row8 col6" >0.1277</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ddb68_row9_col0" class="data row9 col0" >0.4020</td>
#       <td id="T_ddb68_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_ddb68_row9_col2" class="data row9 col2" >0.4020</td>
#       <td id="T_ddb68_row9_col3" class="data row9 col3" >0.8891</td>
#       <td id="T_ddb68_row9_col4" class="data row9 col4" >0.5095</td>
#       <td id="T_ddb68_row9_col5" class="data row9 col5" >0.0902</td>
#       <td id="T_ddb68_row9_col6" class="data row9 col6" >0.1770</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ddb68_row10_col0" class="data row10 col0" >0.4179</td>
#       <td id="T_ddb68_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_ddb68_row10_col2" class="data row10 col2" >0.4179</td>
#       <td id="T_ddb68_row10_col3" class="data row10 col3" >0.8848</td>
#       <td id="T_ddb68_row10_col4" class="data row10 col4" >0.5266</td>
#       <td id="T_ddb68_row10_col5" class="data row10 col5" >0.0871</td>
#       <td id="T_ddb68_row10_col6" class="data row10 col6" >0.1683</td>
#     </tr>
#     <tr>
#       <th id="T_ddb68_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ddb68_row11_col0" class="data row11 col0" >0.0363</td>
#       <td id="T_ddb68_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_ddb68_row11_col2" class="data row11 col2" >0.0363</td>
#       <td id="T_ddb68_row11_col3" class="data row11 col3" >0.0079</td>
#       <td id="T_ddb68_row11_col4
# Original model was better than the blended model, hence it will be returned. NOTE: The display metrics are for the blended model (not the original one).

# %%
pred = predict_model(blended_models)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b98ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b98ac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b98ac_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b98ac_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b98ac_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b98ac_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b98ac_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b98ac_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b98ac_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b98ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b98ac_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_b98ac_row0_col1" class="data row0 col1" >0.8248</td>
#       <td id="T_b98ac_row0_col2" class="data row0 col2" >0.6577</td>
#       <td id="T_b98ac_row0_col3" class="data row0 col3" >0.8248</td>
#       <td id="T_b98ac_row0_col4" class="data row0 col4" >0.8594</td>
#       <td id="T_b98ac_row0_col5" class="data row0 col5" >0.8381</td>
#       <td id="T_b98ac_row0_col6" class="data row0 col6" >0.1745</td>
#       <td id="T_b98ac_row0_col7" class="data row0 col7" >0.1809</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pull()

# %% [markdown]
# #### Plot the ensemble model

# %%
result.to_csv('multilabel_ensemble.csv')

# %% [markdown]
# #### Finalize and save the ensemble model

# %%
final_best = finalize_model(blended_models)
save_model(final_best, 'multilabel')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['raw_sloc', 'raw_multi',
#                                               'raw_blank', 'raw_single_comments',
#                                               'hal_func_N2',
#                                               'hal_func_vocabulary',
#                                               'hal_func_length',
#                                               'hal_func_calculated_length',...
#                                                                                           random_state=None,
#                                                                                           reg_alpha=0.0,
#                                                                                           reg_lambda=0.0,
#                                                                                           subsample=1.0,
#                                                                                           subsample_for_bin=200000,
#                                                                                           subsample_freq=0),
#                                                                  importance_getter='auto',
#                                                                  max_features=2,
#                                                                  norm_order=1,
#                                                                  prefit=False,
#                                                                  threshold=-inf))),
#                  ('actual_estimator',
#                   KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                        metric='minkowski', metric_params=None,
#                                        n_jobs=-1, n_neighbors=5, p=2,
#                                        weights='uniform'))],
#           verbose=False),
#  'multilabel.pkl')

# %%
import pandas as pd
from pycaret.classification import load_model, predict_model

X = pd.read_csv('test.csv', index_col=0)

m = load_model("multilabel")

result = predict_model(m, data=X, verbose=False)

cols_saida = []
cols_saida += ['prediction_label', 'prediction_score']

print(result[cols_saida].head())
# Out:
# Transformation Pipeline and Model Successfully Loaded
#           prediction_label  prediction_score
# 0  non-long-parameter-list               0.8
# 1              long-method               1.0
# 2  non-long-parameter-list               0.6
